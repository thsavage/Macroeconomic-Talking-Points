# %% [markdown]
# # *Counselors of Real Estate* Top Ten Issues
# ## Issue 4: AI - How Intelligent Is It?
#
# ## Timothy H. Savage, Ph.D. CRE
# ### NYU Schack Institute of Real Estate
# ### Chief Economist | Haystacks.AI

# %%
# %matplotlib inline
from IPython.display import Image
import urllib.request as url
import io
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels as sm
import statsmodels.formula.api as smf
import statsmodels.api as sma
import patsy
from statsmodels.graphics.api import abline_plot
import numpy.linalg as linalg
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)

import datetime as dt
from fredapi import Fred
fred = Fred(api_key='30e6ecb242a73869e11cb35f6aa3afc3')
from IPython.display import Image

# %% [markdown]
# ### Housekeeping Note
#
# * Topic did not register among Counselors in the original winter survey.
# * Given ChatGPT's rapid development, it merited top-10 status.
# * Savage wrote the piece based on his knowledge and experience.

# %%
url = 'https://scpr.brightspotcdn.com/dims4/default/e5892e5/2147483647/strip/true/crop/640x465+0+0/resize/1760x1278!/format/webp/quality/90/?url=http%3A%2F%2Fscpr-brightspot.s3.amazonaws.com%2Flegacy%2Fi%2F59e765bcb2815405af848a283a51e03b%2F5b2a66310161a1000dd776f2-original.jpg'
Image(url, width=600, height=600)

# %%
url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/05/R2-D2_-_Genuine_Movie_Star.jpg/440px-R2-D2_-_Genuine_Movie_Star.jpg'
Image(url, width=350, height=350)

# %%
url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Amazon_warehouse_robot_2020.JPG/440px-Amazon_warehouse_robot_2020.JPG'
Image(url, width=600, height=600)

# %% [markdown]
# ### Overview
#
# * ChatGPT and its evolultion since January has thrust AI into the lexicon.
# * It has evoked considerable attention since January.
#     * *It will kill us*.
#     * *It will befriend and help us*.
#     * *It will move things around*.
# * **Statistical learning algorithms** (AI) have been used since Gauss.
# * The purpose of this Top Ten Issue is highlight its historical relevance.
#     * **It will befriend and help us**.

# %% [markdown]
# ### The AI Lifecycle in Real Estate
#
# * A brief history of time (some items omitted for brevity).
# * **Feedback welcome**.

# %% [markdown]
# ### AI 1.0
#
# * The creation of the GSEs to provide liquidity.
# * Real estate as a distinct asset class with trained professionals.
#     * Larry Silverstein founds the NYU Real Estate Institute in 1967.
#     * The Counselors assist to create the MIT Center for Real Estate.
# * Basic data collection and the creation of basic accounting standards.
#     * NCREIF.
#     * Real Capital Analytics.
#     * Torto-Wheaton Research.

# %% [markdown]
# ### AI 2.0
#
# * With sufficient time series data:
#     * Indices to measure quarterly returns.
#     * Forecasting.

# %% [markdown]
# ### AI 3.0
#
# * The incorporation of **massive data**.
# * The use of **new methods** of statistical learning.
#     * Bayes (simulation) and Pearl (causation).
# * The importance of **accuracy, granularity and timeliness**.
#     * Quarterly forecasts will go the way of frequentism.
# * **It will befriend and help us make decisions in logically-coherent ways**.

# %% [markdown]
# ### And ChatGPT?
#
# * Try it for yourself, but use it on **different devices**.
#     * Ask it basic questions to examine its different answers.
# * It will it help with routine tasks, such as leases and contracts.
# * AI is only as intelligent as the data on which it trains.
#     * **GIGO** still rules.
#     * **Accuracy, granularity and timeliness**.
